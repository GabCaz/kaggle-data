# %% [markdown]
# # Feature Importance

# %%
from matplotlib import pyplot as plt
from kaggle_house_prices.src.features import get_x_y, load_data, make_mi_scores


df_train, _ = load_data()
X, y = get_x_y(data=df_train)
mi_scores = make_mi_scores(X, y)

# %%
mi_scores.head(10)
# Out:
# OverallQual     0.570005
# Neighborhood    0.525052
# GrLivArea       0.430629
# YearBuilt       0.404620
# LotArea         0.399516
# GarageCars      0.361218
# TotalBsmtSF     0.360842
# GarageArea      0.360014
# BsmtQual        0.328123
# ExterQual       0.325156
# Name: MI Scores, dtype: float64

# %%
import numpy as np


def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plot_mi_scores(scores=mi_scores.head(30))
plt.tight_layout()
plt.show()
