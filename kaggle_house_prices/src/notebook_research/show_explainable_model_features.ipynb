# %% [markdown]
# # Show Feature Importance in the Models

# %%
from kaggle_house_prices.src.model_feature_importance import compute_and_show_rf_importance

compute_and_show_rf_importance()

# %%
from kaggle_house_prices.src.model_feature_importance import compute_and_show_xgb_importance

compute_and_show_xgb_importance()
